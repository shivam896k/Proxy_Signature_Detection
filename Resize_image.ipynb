# %%
from PIL import Image
import numpy as np
import sys
import os
import csv

import numpy as np
import pandas as pd

import glob
from random import shuffle
import h5py
import numpy as np
import cv2
import math
import time
import matplotlib.pyplot as plt
# %matplotlib inline
from tqdm import tqdm_notebook

import PIL
from PIL import Image

# %%
def createFolder(directory):
    try:
        if not os.path.exists(directory):
            os.makedirs(directory)
    except OSError:
        print ('Error: Creating directory. ' + directory)

# %%
#Useful function
def createFileList(myDir, format='.jpg'):
    fileList = []
    print(myDir)
    for root, dirs, files in os.walk(myDir, topdown=False):
        for name in files:
            if name.endswith(format):
                fullName = os.path.join(root, name)
                fileList.append(fullName)
    return fileList

# %%
def load_image(infilename) :
    img = Image.open(infilename)
    img.load()
    data = np.array( img, dtype="int32" )
    data = data.reshape(600, 300)
    data = data.flatten()
    return data

# %%
for i in tqdm_notebook(range(1, 213)):
    
    myFileList = createFileList('/home/shivam/data/signature_data/folder{}'.format(i))
    
    for file in myFileList:
        img = Image.open(file).convert('L')
        img = img.resize((600, 300), PIL.Image.ANTIALIAS)
        createFolder('/home/shivam/data/signature_data_csv/folder{}'.format(i))
        img.save('/home/shivam/data/signature_data_csv/folder{}/{}'.format(i, os.path.basename(file)))
# Out:
# ...
# /home/shivam/data/signature_data/folder1
# /home/shivam/data/signature_data/folder2
# /home/shivam/data/signature_data/folder3
# /home/shivam/data/signature_data/folder4
# /home/shivam/data/signature_data/folder5
# /home/shivam/data/signature_data/folder6
# /home/shivam/data/signature_data/folder7
# /home/shivam/data/signature_data/folder8
# /home/shivam/data/signature_data/folder9
# /home/shivam/data/signature_data/folder10
# /home/shivam/data/signature_data/folder11
# /home/shivam/data/signature_data/folder12
# /home/shivam/data/signature_data/folder13
# /home/shivam/data/signature_data/folder14
# /home/shivam/data/signature_data/folder15
# /home/shivam/data/signature_data/folder16
# /home/shivam/data/signature_data/folder17
# /home/shivam/data/signature_data/folder18
# /home/shivam/data/signature_data/folder19
# /home/shivam/data/signature_data/folder20
# /home/shivam/data/signature_data/folder21
# /home/shivam/data/signature_data/folder22
# ...
